# %%
import sys
sys.path.insert(0, "/Users/pablolastrabachmann/DiploGenAI")  # raíz del repo

from final_proyect.med_agent.graph import build_graph
g = build_graph()

from IPython.display import Image, display
display(Image(g.get_graph().draw_mermaid_png()))
# Si no tienes draw_mermaid_png:
# print(g.get_graph().draw_mermaid())
